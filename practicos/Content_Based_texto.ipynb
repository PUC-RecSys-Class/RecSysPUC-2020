# %% [markdown]
# # Práctico Content-based (Texto)
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/drive/1HJQxuIIhQIrvKJJv1VtkxK4VGsAUr5lY?usp=sharing)
#
# **Profesor:** Denis Parra
#
# **Ayudantes:** Vladimir Araujo, Andrés Carvallo, Manuel Cartagena, Francisca Catán, Andres Villa
#
#
# En este proyecto trabajaremos con un modelo de recomendacion de libros de la página [Goodreads](http://www.goodreads.com). El modelo de recomendación de libros es un recomendador basado en contenido, donde se utilizan modelos de lenguage BERT y BERT-large para el cálculo de embeddings de los libros y luego similaridades de ítems. Luego, dependiendo de los libros con los que el usuario ha interactuado, se recomiendan los ítems más similares.

# %%
import numpy as np
import json
import requests
import heapq
import math
import matplotlib.pyplot as plt
from sklearn.metrics import pairwise_distances
from sklearn.decomposition import PCA
from io import BytesIO
import pickle
import pandas as pd
import time

# %% [markdown]
# Descargamos datos que vienen previamente calculados:
# - transacciones/interacciones de cada usuario
# - transaciones para evaluar el modelo
# - embeddings de imágenes calculados con BERT
# - embeddings de imágenes calculados con BERT-large
# - datos de libros con información de titulo, descripcion, año de publicacion, entre otros.

# %%
# !wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=1Q2wix9sRn7lEwPtnUDf70cewi9sAeVVW' -O books.tsv
# !wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=1qzt5Fxrf1KimlEqyKLNCc2UwxrOj6yAb' -O goodreads_bert_embeddings.npy
# !wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=1Sls46iCyO__PU6d9FCO05loumYaooY_P' -O goodreads_bert_large_embeddings.npy
# !wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=1BxNu7OwSz9zi20Ss120qG77BE3vNt4TG' -O goodreads_past_interactions.json
# !wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=1t5PIqci6UrWW1Qp8rtbaZz-GunnZu0zN' -O goodreads_test_interactions.json
# Out:
# --2020-09-05 16:47:25--  https://docs.google.com/uc?export=download&id=1Q2wix9sRn7lEwPtnUDf70cewi9sAeVVW
# Resolving docs.google.com (docs.google.com)... 172.217.203.101, 172.217.203.113, 172.217.203.100, ...
# Connecting to docs.google.com (docs.google.com)|172.217.203.101|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-0o-4g-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/c443ogu7de1atnufa8qi5fuosie2vq5c/1599324375000/01180867749262413309/*/1Q2wix9sRn7lEwPtnUDf70cewi9sAeVVW?e=download [following]
# Warning: wildcards not supported in HTTP.
# --2020-09-05 16:47:26--  https://doc-0o-4g-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/c443ogu7de1atnufa8qi5fuosie2vq5c/1599324375000/01180867749262413309/*/1Q2wix9sRn7lEwPtnUDf70cewi9sAeVVW?e=download
# Resolving doc-0o-4g-docs.googleusercontent.com (doc-0o-4g-docs.googleusercontent.com)... 173.194.216.132, 2607:f8b0:400c:c12::84
# Connecting to doc-0o-4g-docs.googleusercontent.com (doc-0o-4g-docs.googleusercontent.com)|173.194.216.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/tab-separated-values]
# Saving to: ‘books.tsv’
#
# books.tsv               [ <=>                ]   5.54M  --.-KB/s    in 0.05s
#
# 2020-09-05 16:47:26 (121 MB/s) - ‘books.tsv’ saved [5814576]
#
# --2020-09-05 16:47:26--  https://docs.google.com/uc?export=download&id=1qzt5Fxrf1KimlEqyKLNCc2UwxrOj6yAb
# Resolving docs.google.com (docs.google.com)... 172.217.203.138, 172.217.203.101, 172.217.203.102, ...
# Connecting to docs.google.com (docs.google.com)|172.217.203.138|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-10-4g-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/7mbik55jrg915g0obejdcto0u7eour9e/1599324375000/01180867749262413309/*/1qzt5Fxrf1KimlEqyKLNCc2UwxrOj6yAb?e=download [following]
# Warning: wildcards not supported in HTTP.
# --2020-09-05 16:47:28--  https://doc-10-4g-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/7mbik55jrg915g0obejdcto0u7eour9e/1599324375000/01180867749262413309/*/1qzt5Fxrf1KimlEqyKLNCc2UwxrOj6yAb?e=download
# Resolving doc-10-4g-docs.googleusercontent.com (doc-10-4g-docs.googleusercontent.com)... 173.194.216.132, 2607:f8b0:400c:c12::84
# Connecting to doc-10-4g-docs.googleusercontent.com (doc-10-4g-docs.googleusercontent.com)|173.194.216.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/octet-stream]
# Saving to: ‘goodreads_bert_embeddings.npy’
#
# goodreads_bert_embe     [ <=>                ]  27.96M   177MB/s    in 0.2s
#
# 2020-09-05 16:47:28 (177 MB/s) - ‘goodreads_bert_embeddings.npy’ saved [29313152]
#
# --2020-09-05 16:47:28--  https://docs.google.com/uc?export=download&id=1Sls46iCyO__PU6d9FCO05loumYaooY_P
# Resolving docs.google.com (docs.google.com)... 172.217.203.113, 172.217.203.102, 172.217.203.138, ...
# Connecting to docs.google.com (docs.google.com)|172.217.203.113|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-04-4g-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/lcemfvpidbf97k3te527p95h92ebjg16/1599324450000/01180867749262413309/*/1Sls46iCyO__PU6d9FCO05loumYaooY_P?e=download [following]
# Warning: wildcards not supported in HTTP.
# --2020-09-05 16:47:30--  https://doc-04-4g-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/lcemfvpidbf97k3te527p95h92ebjg16/1599324450000/01180867749262413309/*/1Sls46iCyO__PU6d9FCO05loumYaooY_P?e=download
# Resolving doc-04-4g-docs.googleusercontent.com (doc-04-4g-docs.googleusercontent.com)... 173.194.216.132, 2607:f8b0:400c:c12::84
# Connecting to doc-04-4g-docs.googleusercontent.com (doc-04-4g-docs.googleusercontent.com)|173.194.216.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/octet-stream]
# Saving to: ‘goodreads_bert_large_embeddings.npy’
#
# goodreads_bert_larg     [   <=>              ]  37.27M  48.3MB/s    in 0.8s
#
# 2020-09-05 16:47:32 (48.3 MB/s) - ‘goodreads_bert_large_embeddings.npy’ saved [39084160]
#
# --2020-09-05 16:47:32--  https://docs.google.com/uc?export=download&id=1BxNu7OwSz9zi20Ss120qG77BE3vNt4TG
# Resolving docs.google.com (docs.google.com)... 172.217.203.139, 172.217.203.113, 172.217.203.102, ...
# Connecting to docs.google.com (docs.google.com)|172.217.203.139|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-00-4g-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/7iiuagum633qiqt90kv8063dbe5mejvp/1599324450000/01180867749262413309/*/1BxNu7OwSz9zi20Ss120qG77BE3vNt4TG?e=download [following]
# Warning: wildcards not supported in HTTP.
# --2020-09-05 16:47:32--  https://doc-00-4g-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/7iiuagum633qiqt90kv8063dbe5mejvp/1599324450000/01180867749262413309/*/1BxNu7OwSz9zi20Ss120qG77BE3vNt4TG?e=download
# Resolving doc-00-4g-docs.googleusercontent.com (doc-00-4g-docs.googleusercontent.com)... 173.194.216.132, 2607:f8b0:400c:c12::84
# Connecting to doc-00-4g-docs.googleusercontent.com (doc-00-4g-docs.googleusercontent.com)|173.194.216.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 166662 (163K) [application/json]
# Saving to: ‘goodreads_past_interactions.json’
#
# goodreads_past_inte 100%[===================>] 162.76K  --.-KB/s    in 0.002s
#
# 2020-09-05 16:47:32 (94.8 MB/s) - ‘goodreads_past_interactions.json’ saved [166662/166662]
#
# --2020-09-05 16:47:32--  https://docs.google.com/uc?export=download&id=1t5PIqci6UrWW1Qp8rtbaZz-GunnZu0zN
# Resolving docs.google.com (docs.google.com)... 172.217.203.102, 172.217.203.139, 172.217.203.101, ...
# Connecting to docs.google.com (docs.google.com)|172.217.203.102|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-0g-4g-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/4pmhfecp2pjkr6imbquahn621mbd89jh/1599324450000/01180867749262413309/*/1t5PIqci6UrWW1Qp8rtbaZz-GunnZu0zN?e=download [following]
# Warning: wildcards not supported in HTTP.
# --2020-09-05 16:47:33--  https://doc-0g-4g-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/4pmhfecp2pjkr6imbquahn621mbd89jh/1599324450000/01180867749262413309/*/1t5PIqci6UrWW1Qp8rtbaZz-GunnZu0zN?e=download
# Resolving doc-0g-4g-docs.googleusercontent.com (doc-0g-4g-docs.googleusercontent.com)... 173.194.216.132, 2607:f8b0:400c:c12::84
# Connecting to doc-0g-4g-docs.googleusercontent.com (doc-0g-4g-docs.googleusercontent.com)|173.194.216.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 155925 (152K) [application/json]
# Saving to: ‘goodreads_test_interactions.json’
#
# goodreads_test_inte 100%[===================>] 152.27K  --.-KB/s    in 0.002s
#
# 2020-09-05 16:47:33 (97.2 MB/s) - ‘goodreads_test_interactions.json’ saved [155925/155925]

# %%
ls
# Out:
# assets.tar.gz                  goodreads_bert_large_embeddings.npy
# books.tsv                      goodreads_past_interactions.json
# FILENAME                       goodreads_test_interactions.json
# goodreads_bert_embeddings.npy  sample_data/

# %% [markdown]
# # Cargar datos adicionales

# %%
df_books = pd.read_csv('books.tsv', sep='\t')
df_books.head()
# Out:
#    id  ...                                   book_description
# 0   1  ...  Winning will make you famous. Losing means cer...
# 1   2  ...  Harry Potter's life is miserable. His parents ...
# 2   3  ...  About three things I was absolutely positive.F...
# 3   4  ...  The unforgettable novel of a childhood in a sl...
# 4   5  ...  THE GREAT GATSBY, F. Scott Fitzgerald’s third ...
#
# [5 rows x 24 columns]

# %%
# diccionario con id del usuario y id de libros con los que ha interactuado en el pasado 
with open('goodreads_past_interactions.json') as f:
    user_interactions = json.load(f)

# diccionario con id del usuario y id de libros para testear el modelo     
with open('goodreads_test_interactions.json') as f:
    user_interactions_test = json.load(f)

# %%
user_interactions
# Out:
# {'49152': [343, 359, 360, 447, 703],
#  '49154': [3368],
#  '27307': [1625],
#  '32773': [865, 1097, 1617],
#  '7': [3711, 4138],
#  '32776': [4887, 6185],
#  '16402': [4630],
#  '16403': [34, 447, 676],
#  '16404': [1911, 2165],
#  '16405': [8337],
#  '23': [8698],
#  '49179': [1295, 4662],
#  '18550': [6, 50, 359, 431, 760],
#  '16415': [629],
#  '49184': [760, 2156, 3750],
#  '16417': [998, 1622],
#  '32802': [4796],
#  '35': [249, 1005],
#  '49188': [4948],
#  '16421': [456, 816, 1420],
#  '32807': [7069],
#  '32809': [359, 816],
#  '32810': [900],
#  '32811': [1067, 1232],
#  '16429': [3473, 5759],
#  '49198': [3478],
#  '49203': [1618],
#  '49204': [8127],
#  '16441': [4631],
#  '21855': [2159, 7058],
#  '16445': [1842],
#  '32831': [3110],
#  '49216': [4929],
#  '16453': [4954],
#  '49222': [827, 1097],
#  '32841': [676, 2517],
#  '75': [668, 968],
#  '16460': [1420],
#  '32845': [1431, 2517],
#  '32848': [2054, 2767],
#  '16465': [2839, 5187],
#  '82': [3679],
#  '49236': [2932],
#  '32853': [5659],
#  '44739': [3980],
#  '32856': [3103, 4138],
#  '16473': [3758, 3974],
#  '32858': [7058],
#  '40975': [360, 446, 890, 1622],
#  '16476': [1301, 1426, 1842, 1911, 3698],
#  '32865': [5171, 7911],
#  '49251': [1067, 1171, 1232],
#  '49254': [1898],
#  '32872': [1103],
#  '32876': [3304, 3762, 4271],
#  '49262': [348, 1852, 5171],
#  '49263': [4865],
#  '16496': [3103],
#  '32885': [2052, 3698],
#  '49272': [827, 1428],
#  '124': [2165],
#  '32894': [4264],
#  '49279': [4701, 4978],
#  '10944': [1, 2, 5, 11, 13, 21, 24],
#  '49282': [1898, 1911],
#  '32900': [5171],
#  '133': [2744],
#  '35466': [3473, 6531],
#  '19137': [3876, 4630],
#  '32904': [5246],
#  '49289': [3, 11, 13, 33, 34, 106, 348, 360],
#  '32906': [5345],
#  '32907': [668, 1097, 1911, 3102, 3685],
#  '49295': [3, 11, 13, 33, 34, 50, 106, 348, 360],
#  '49297': [3, 11, 13, 33, 34, 50, 106, 348, 360],
#  '16530': [4395],
#  '49299': [1824, 1848, 2050, 2880, 3473],
#  '32916': [249, 378, 662, 816],
#  '46446': [3980],
#  '32918': [2, 3, 13, 21, 24, 25],
#  '153': [3805],
#  '32923': [1, 5, 6, 11, 28, 33],
#  '49308': [6671],
#  '16541': [760],
#  '158': [976, 1633, 1633],
#  '16543': [2612, 4473],
#  '32929': [5015],
#  '16550': [3805],
#  '32937': [1078],
#  '32938': [4364],
#  '32940': [4004],
#  '173': [6, 249],
#  '32943': [2767],
#  '49329': [870, 968],
#  '178': [662, 816],
#  '16564': [2122],
#  '49333': [4701],
#  '32951': [2623],
#  '32952': [320],
#  '16569': [6, 11, 13, 24, 25, 28],
#  '16573': [360, 365, 706],
#  '16575': [1622, 3758],
#  '49344': [5368],
#  '16577': [1911, 2373],
#  '32962': [1295, 3980, 4662],
#  '21878': [968, 5205],
#  '40993': [827, 1824],
#  '202': [447, 760],
#  '16587': [760, 960, 998, 1898, 3478],
#  '204': [4796],
#  '206': [4671],
#  '207': [5114],
#  '213': [2175],
#  '215': [2873, 3758],
#  '16600': [7058],
#  '218': [5091, 5346],
#  '16603': [1295, 3980, 4662],
#  '32990': [1241],
#  '8229': [1848, 2050],
#  '16609': [5091, 5479],
#  '32994': [5211],
#  '16612': [3636],
#  '16614': [3368, 3867],
#  '16618': [4806],
#  '16621': [8698],
#  '13693': [1911, 2165, 6288],
#  '244': [3679, 3974],
#  '49397': [827, 2932, 4339],
#  '41': [1824],
#  '16634': [2165],
#  '251': [2865, 4796],
#  '252': [3867],
#  '16637': [2165, 4339],
#  '19157': [830, 3636],
#  '256': [668],
#  '16642': [890],
#  '49412': [4271],
#  '16647': [4407],
#  '16652': [4406, 5129],
#  '33037': [475, 1426],
#  '16656': [4264],
#  '33041': [976],
#  '274': [249, 599],
#  '16662': [599, 760, 960],
#  '33047': [3507, 6185],
#  '16664': [5094],
#  '33049': [3836],
#  '16668': [2122, 4887],
#  '33053': [3467, 3507, 5171, 6185],
#  '33054': [5479],
#  '287': [5439],
#  '16672': [8852],
#  '289': [5203],
#  '16675': [1371],
#  '33065': [1, 2, 5, 13, 21, 24, 25, 28],
#  '33068': [5246],
#  '33069': [998, 1845],
#  '33074': [3980, 4929],
#  '33075': [355, 431, 446],
#  '21497': [8073],
#  '16694': [5168],
#  '314': [1, 3, 5, 6, 29, 106],
#  '21818': [6295],
#  '33085': [1618],
#  '16703': [2372],
#  '321': [1624],
#  '49474': [1295, 7815],
#  '324': [2052],
#  '41014': [976, 5351],
#  '16711': [1715],
#  '13708': [7035],
#  '33100': [2744],
#  '16717': [5129],
#  '33102': [2156, 2623],
#  '16720': [5659],
#  '33105': [1898, 2517],
#  '49491': [343, 357, 1622, 1934],
#  '341': [3711],
#  '33110': [2372, 2744],
#  '343': [870, 1301],
#  '14196': [1824],
#  '5467': [1103, 2547],
#  '349': [900, 3581, 3590],
#  '16735': [2865, 4271, 5114],
#  '356': [4630, 5113],
#  '33127': [1171, 1617, 2203],
#  '16744': [1078],
#  '49514': [122, 431],
#  '363': [1067, 1232],
#  '16749': [656, 6541],
#  '366': [1624],
#  '49519': [5805, 7244],
#  '33136': [900],
#  '49523': [4630],
#  '16757': [3102],
#  '376': [1624, 3483],
#  '33147': [6, 21, 25, 50, 106, 295, 359, 703],
#  '381': [1633, 3758],
#  '16769': [4662, 7036],
#  '16770': [998, 1005],
#  '49540': [275, 880, 1934, 3103],
#  '13718': [4954],
#  '49543': [2183, 4662, 5190],
#  '43756': [2137, 3507],
#  '49547': [2767],
#  '8258': [456, 1202, 1319],
#  '16782': [1875, 3762],
#  '400': [1624],
#  '13720': [4934],
#  '33170': [1295, 2183, 4008],
#  '16789': [4271],
#  '49559': [1301, 3273],
#  '16793': [2175],
#  '49564': [1428],
#  '49566': [7194, 7445],
#  '41029': [3102, 4982],
#  '27376': [3636, 4339],
#  '16804': [6310],
#  '49573': [365, 599],
#  '33191': [676, 2932],
#  '424': [275, 348],
#  '426': [4137],
#  '33203': [3110],
#  '33204': [4406],
#  '16821': [662, 1875],
#  '16822': [9539],
#  '33207': [6, 320, 359],
#  '16827': [4588],
#  '33212': [3762],
#  '16829': [3102],
#  '446': [1426, 1430],
#  '447': [2054, 2054],
#  '33216': [2526],
#  '48776': [3473, 4069],
#  '451': [5755],
#  '454': [3581],
#  '16841': [3562],
#  '33227': [4271],
#  '461': [1911, 5187],
#  '16848': [355, 415, 449],
#  '466': [2839],
#  '33237': [5096, 5246],
#  '33241': [1618],
#  '16859': [275, 475],
#  '476': [3476, 3872],
#  '33245': [2623, 5211],
#  '16464': [3109],
#  '33250': [4934],
#  '49635': [2050, 2372],
#  '49636': [348],
#  '16870': [976, 4138],
#  '487': [4137],
#  '16873': [2880, 7672],
#  '491': [5346, 5527],
#  '16876': [2744],
#  '16466': [1420, 2052],
#  '494': [4887],
#  '49651': [7061],
#  '16884': [5472],
#  '33269': [5053],
#  '13737': [1427, 1617],
#  '33272': [4264],
#  '24117': [2159, 5171],
#  '27295': [1295, 2122],
#  '49661': [415, 1617],
#  '49663': [7199],
#  '513': [1953, 2049],
#  '13739': [1301, 1426, 1842],
#  '33285': [4339, 4948],
#  '519': [3985],
#  '16904': [656],
#  '49673': [2767, 6419],
#  '33293': [4900],
#  '33296': [2373, 7733],
#  '16913': [1, 3, 6, 11, 21, 24, 25, 28],
#  '33298': [900],
#  '16915': [2052],
#  '46510': [7432],
#  '49688': [5171, 6294, 7911],
#  '48573': [1078, 3109],
#  '16922': [5064],
#  '33307': [449, 1431, 1617],
#  '27398': [365, 976, 998],
#  '49703': [4339],
#  '52938': [1911, 3682],
#  '33322': [5038],
#  '33323': [7911, 7996],
#  '557': [2623, 4985, 5203],
#  '33326': [449, 656],
#  '13112': [1202, 1431],
#  '33328': [3109, 3750],
#  '16945': [5114, 5351],
#  '33337': [378, 816],
#  '16955': [5091],
#  '573': [3679],
#  '33343': [8765],
#  '49733': [1241, 3273],
#  '16970': [3750],
#  '46519': [3466, 3867],
#  '588': [1, 11, 21, 24, 25, 29, 33, 50],
#  '589': [447, 599, 760],
#  '15841': [3750],
#  '49749': [1078, 3758],
#  '16982': [6689],
#  '13753': [2373],
#  '49752': [275, 355, 880, 1554],
#  '606': [1617, 3985, 5187],
#  '33378': [5186],
#  '21947': [2165, 3836],
#  '16996': [2183, 4008],
#  '32870': [4395, 7332],
#  '49766': [3679],
#  '6878': [6327],
#  '33384': [6588],
#  '33390': [4820, 4989],
#  '17009': [2049, 2612],
#  '17013': [2493, 2623],
#  '49783': [3412, 3467],
#  '17017': [2187],
#  '17018': [4796],
#  '33403': [5114],
#  '17020': [2050, 2373],
#  '49790': [6900],
#  '43797': [2880],
#  '33409': [275, 350, 360, 599],
#  '2838': [1319],
#  '33417': [3867, 4004],
#  '17039': [1524, 5297],
#  '657': [6150, 7244],
#  '17044': [5472],
#  '8302': [249, 662, 703],
#  '17051': [4985],
#  '17052': [4473, 4671],
#  '49823': [4264],
#  '33440': [1371],
#  '29832': [816, 870],
#  '676': [3476],
#  '33445': [4136],
#  '49830': [6, 34, 275],
#  '33450': [827],
#  '33454': [1295],
#  '33455': [50, 249, 930],
#  '17073': [890, 2666],
#  '690': [5114],
#  '49843': [5168],
#  '17078': [1625],
#  '17080': [7244],
#  '17081': [3698],
#  '49850': [1301],
#  '33467': [4692],
#  '17086': [3636, 3974],
#  '33471': [2794, 5872],
#  '17088': [1428],
#  '33473': [359, 378, 1202, 2839],
#  '33474': [5872],
#  '712': [3476],
#  '38348': [4069, 4934],
#  '49867': [5759, 6531],
#  '33484': [6310],
#  '35618': [1381, 1622],
#  '17104': [1295, 3008, 5190],
#  '17105': [50, 106, 122, 350],
#  '725': [6, 106, 275, 295],
#  '726': [1624],
#  '33497': [6858],
#  '17114': [5954],
#  '732': [2175],
#  '17117': [6514],
#  '49886': [3758, 4687],
#  '33503': [676, 1295, 3980],
#  '736': [275],
#  '49889': [2159],
#  '8315': [3805],
#  '33509': [5064],
#  '17127': [7909],
#  '8316': [3974, 5826],
#  '17130': [1067, 1232],
#  '52007': [295, 431, 703],
#  '33516': [3836],
#  '17135': [4900],
#  '33522': [5470, 7035],
#  '8318': [5454],
#  '33527': [295, 447, 760],
#  '17144': [3872, 4887],
#  '762': [4473, 5043],
#  '17148': [3368],
#  '766': [2165],
#  '17157': [3008, 5096],
#  '33546': [3466],
#  '33547': [1848],
#  '49934': [1554, 3974],
#  '49935': [2612, 5091],
#  '33555': [706, 1420, 1953],
#  '33556': [976, 1591],
#  '33557': [1624, 3412],
#  '49942': [3805],
#  '33560': [1428],
#  '17177': [2744, 4395],
#  '49947': [4978, 5470],
#  '797': [3102, 3412],
#  '33567': [4271],
#  '800': [5205],
#  '19248': [1426, 2657],
#  '17189': [3008],
#  '14408': [1618],
#  '17193': [1554, 3473],
#  '33580': [3109],
#  '19250': [816],
#  '33582': [8765],
#  '17199': [2612],
#  '49968': [1428],
#  '33585': [2052, 2873],
#  '17203': [4406],
#  '49972': [4364],
#  '49973': [2932],
#  '17207': [447, 1171],
#  '49976': [1420, 2517],
#  '49978': [976, 1426, 1427, 1842, 5129],
#  '827': [3985],
#  '828': [4820, 4887],
#  '49982': [8088],
#  '33599': [415, 475, 656, 827],
#  '17216': [365, 629, 890],
#  '836': [5826],
#  '33606': [6588, 9717],
#  '17224': [6138],
#  '33609': [2666, 5015, 5203],
#  '11063': [1381, 1898, 2493],
#  '17228': [5, 29, 50, 93, 599],
#  '49998': [760],
#  '33615': [2203],
#  '33616': [3412],
#  '849': [3103],
#  '50002': [1427, 2156, 4806],
#  '49129': [2122, 2623],
#  '33621': [275, 355],
#  '854': [2373, 5043, 5129],
#  '17239': [7199],
#  '856': [1371, 3581],
#  '33625': [2187, 3483],
#  '858': [870],
#  '17243': [6327],
#  '33632': [7745],
#  '33633': [320, 662, 760],
#  '50022': [4900, 5114],
#  '50023': [662, 816, 3869],
#  '14954': [4364],
#  '873': [2932, 3867],
#  '33642': [656, 827, 830, 5205],
#  '49298': [1, 2, 11, 21, 24, 25, 67],
#  '46568': [4965, 6541],
#  '883': [968],
#  '17269': [4631],
#  '17270': [4934],
#  '33655': [1295, 4954, 5096],
#  '50040': [3467],
#  '889': [1241, 3466],
#  '33662': [449, 2183],
#  '895': [1591, 3562],
#  '33665': [5346, 5509],
#  '17282': [4264],
#  '17285': [4069],
#  '50055': [6424, 7445],
#  '907': [1319],
#  '17292': [968, 3682],
#  '33677': [5171, 7996],
#  '33679': [5015, 5168],
#  '50064': [3562],
#  '50065': [2203],
#  '17300': [2794],
#  '50069': [5932],
#  '8345': [3562],
#  '17304': [4934],
#  '19268': [1911, 5349],
#  '922': [1524],
#  '923': [3974, 4806],
#  '12663': [6150],
#  '17310': [2744, 3636],
#  '33697': [1, 2, 5, 13, 21, 24, 25],
#  '931': [968, 1898],
#  '17316': [1420, 1875, 3698],
#  '50085': [5246],
#  '33704': [4929],
#  '50089': [5509],
#  '17322': [3466],
#  '17323': [4796, 5168],
#  '50094': [6628],
#  '943': [3836],
#  '33712': [3103],
#  '33713': [355, 360, 960, 2493],
#  '946': [320, 662],
#  '50100': [827],
#  '33717': [4952],
#  '50102': [3, 6, 34, 50, 348, 360],
#  '951': [50, 122, 357, 360, 446],
#  '50104': [1, 2, 3, 5, 6, 11, 13, 33, 34, 50],
#  '22004': [7672],
#  '33723': [5297],
#  '958': [1852],
#  '17343': [2442, 4473],
#  '33728': [3805],
#  '965': [5186],
#  '50119': [446, 998],
#  '33736': [5246, 7445],
#  '33739': [1618],
#  '17356': [2183],
#  '973': [2865],
#  '17359': [343],
#  '17360': [5107],
#  '17361': [3109, 5187],
#  '50130': [1319, 1617],
#  '50133': [2, 3, 6, 11, 13, 33, 34, 50, 348],
#  '50137': [4407],
#  '50141': [4364],
#  '17375': [4820, 4989],
#  '994': [2165],
#  '33763': [6424, 7061],
#  '33764': [1617, 1934, 2493],
#  '997': [706, 1420, 2199],
#  '35665': [4952, 5107],
#  '17385': [6748],
#  '1002': [5826],
#  '33772': [960, 1591],
#  '1005': [5346],
#  '50158': [3682],
#  '22013': [2623, 3562, 5203],
#  '17392': [4887],
#  '33777': [2767],
#  '52051': [1381, 1911],
#  '46590': [4929, 4954, 5190],
#  '1014': [3974],
#  '41129': [3762, 5345],
#  '1017': [2839],
#  '1019': [475],
#  '17404': [348, 3109],
#  '17405': [6, 34, 249, 320],
#  '1022': [1371, 3478],
#  '33792': [2156, 2187],
#  '17418': [656, 1618, 1824],
#  '19287': [4887],
#  '47907': [2880],
#  '1037': [249, 816],
#  '1038': [1005, 1171],
#  '50191': [3980],
#  '1041': [2493],
#  '8218': [1241, 1618, 1715, 2839],
#  '33815': [870, 3109, 3590],
#  '50200': [2956],
#  '50202': [7911, 7996],
#  '49327': [656, 827],
#  '50204': [449, 1824, 2050],
#  '50205': [4982],
#  '17438': [3679],
#  '17440': [1953],
#  '1057': [2526],
#  '1059': [5526],
#  '17446': [3867],
#  '1064': [1431, 3304],
#  '17450': [1953, 2199],
#  '33836': [3805, 4982],
#  '33838': [3467, 4671],
#  '1072': [5129, 6539],
#  '17458': [1953],
#  '15857': [676, 2122],
#  '1078': [3656],
#  '1081': [3412, 4473],
#  '1084': [5826],
#  '16565': [3867],
#  '33856': [2373, 4948],
#  '33858': [1241],
#  '17475': [1301, 2050, 2159],
#  '50244': [4796, 6514],
#  '50247': [1845, 3109],
#  '33864': [21, 24, 25, 29, 50, 93],
#  '16567': [1625],
#  '17485': [6753],
#  '33872': [1, 2, 5, 11, 28],
#  '50258': [968, 2203],
#  '33875': [4952],
#  '1108': [7779],
#  '33877': [1232],
#  '50262': [2187, 5168],
#  '1115': [870, 900, 2175, 2187],
#  '17502': [5203, 5356],
#  '1119': [3581],
#  '33890': [1, 33, 50, 67, 343],
#  '17507': [5351, 6514],
#  '50277': [3103, 3478],
#  '50279': [5755],
#  '33896': [2767],
#  '33902': [4796],
#  '17519': [6526],
#  '1136': [34, 360, 446, 449],
#  '50289': [355, 880],
#  '17522': [4934, 5297],
#  '50291': [3562, 3762],
#  '1140': [5107],
#  '17525': [275, 355],
#  '19305': [1420, 2052],
#  '1144': [4965],
#  '38420': [1911],
#  '1146': [5346],
#  '32959': [5349],
#  '3857': [5932],
#  '46505': [5364, 7672],
#  '33922': [676],
#  '50309': [830, 5114],
#  '50313': [1381, 1554, 1591, 4339],
#  '50315': [2156, 2666],
#  '17548': [1430, 7733],
#  '50317': [2526],
#  '1167': [4069],
#  '17552': [3980],
#  '1169': [1, 2, 5, 11, 13, 24, 28],
#  '17554': [2050],
#  '17555': [1171, 2052],
#  '50325': [2865],
#  '50326': [816, 1911],
#  '17559': [4136],
#  '33945': [449],
#  '1182': [2767, 2865],
#  '17568': [830, 1824, 1934],
#  '1185': [1, 106, 320, 350, 378],
#  '1187': [2517],
#  '50340': [1524, 2137],
#  '17574': [4264],
#  '33964': [6424],
#  '1198': [2373, 3102],
#  '33969': [2547, 3876, 4820],
#  '50358': [6541],
#  '1207': [5954],
#  '32970': [4264],
#  '33982': [1295],
#  '33983': [5526],
#  '33984': [3467, 3507],
#  '1221': [3273],
#  '33993': [2156],
#  '33994': [5368],
#  '33996': [2159, 4339],
#  '17613': [1005],
#  '17614': [6150],
#  '17617': [1591, 2187],
#  '17618': [7214],
#  '22051': [3483, 4806],
#  '50388': [1898],
#  '34008': [676, 1295, 3980, 4008],
#  '1241': [2526],
#  '34011': [1885, 4820, 4989],
#  '1245': [2623, 4806],
#  '34014': [968, 3682],
#  '50399': [365, 599, 703, 760],
#  '17633': [1624],
#  '34018': [5351],
#  '43899': [3869, 5297],
#  '34020': [5190, 5197],
#  '1255': [1005],
#  '1256': [2137, 5091],
#  '34026': [3273, 4948],
#  '17643': [13, 343, 350, 360, 431, 446],
#  '1263': [4137],
#  '1266': [1524],
#  '17652': [275, 998, 1381],
#  '1269': [6310, 6969],
#  '17654': [1097, 1625],
#  '34039': [4978, 5439],
#  '1277': [6538],
#  '1278': [3985, 5203],
#  '17663': [1, 2, 3, 5, 11, 29, 93, 106],
#  '1280': [2372, 3102],
#  '17665': [320],
#  '17666': [7194],
#  '34051': [2137, 3805],
#  '1285': [1371],
#  '1286': [1845],
#  '1289': [3102],
#  '50442': [2767],
#  '1291': [2122, 3476],
#  '50444': [960, 1381, 3974],
#  '1294': [320, 1171],
#  '1296': [320, 343],
#  '49368': [3679, 4687],
#  '34066': [827, 1430],
#  '17683': [1898],
#  '34072': [2373, 2612],
#  '17690': [6539],
#  '1307': [656, 1067],
#  '34077': [1171, 2372],
#  '34078': [3869],
#  '34079': [816],
#  '34083': [249, 816, 930, 1319],
#  '1317': [5509],
#  '1318': [4137],
#  '17703': [1420],
#  '17704': [3087],
#  '1323': [976, 1301],
#  '50478': [9419],
#  '13875': [6537],
#  '50485': [3869, 4978],
#  '17718': [662, 930],
#  '19337': [2373, 5359],
#  '14229': [2517],
#  '1339': [6751],
#  '1340': [4137],
#  '34111': [1097, 3876],
#  '50498': [4866],
#  '50499': [1295],
#  '34116': [3679],
#  '34118': [5064],
#  '17735': [3087],
#  '1353': [1953],
#  '50506': [5246, 7036],
#  '1355': [449, 1097],
#  '1357': [3869],
#  '34126': [5190],
#  '1359': [2998],
#  '50514': [4264],
#  '50515': [6424, 7036],
#  '1364': [6419],
#  '34135': [3980, 4339],
#  '50521': [6427],
#  '1370': [2187, 3872],
#  '1374': [1591],
#  '1377': [1430, 1842],
#  '34147': [1067, 1232, 2165],
#  '34148': [4008],
#  '1381': [4137, 5349],
#  '17766': [4137, 4473],
#  '1383': [2054],
#  '34152': [3467, 3507],
#  '46652': [3103],
#  '1391': [976],
#  '1393': [706],
#  '13886': [1842, 3763],
#  '41193': [1524],
#  '1401': [5043, 8698],
#  '1402': [2183, 5096],
#  '5695': [1067, 1232],
#  '34172': [3412],
#  '17789': [1371],
#  '1407': [968, 3685],
#  '50560': [6900],
#  '50562': [4271],
#  '1411': [5114],
#  '17796': [3872],
#  '17800': [5114],
#  '17801': [1524],
#  '17802': [6628],
#  '34187': [1295, 5096],
#  '17804': [106, 357],
#  '34189': [3368],
#  '1423': [6858],
#  '34192': [6538],
#  '34193': [703, 1241],
#  '1428': [348, 1371, 3763],
#  '1429': [668, 816],
#  '50582': [365, 446, 706],
#  '50584': [4687, 5308],
#  '17817': [5043],
#  '17819': [5096],
#  '34205': [4588, 5168],
#  '34208': [5472],
#  '50593': [34, 360, 599, 2493, 3483],
#  '34211': [2183, 3980],
#  '17832': [34, 106, 343],
#  '1449': [359, 378, 662, 1005],
#  '50602': [3685],
#  '17835': [1097],
#  '50604': [6853],
#  '1456': [357, 456, 662],
#  '46664': [5015, 5168],
#  '50610': [6, 295, 350],
#  '50612': [2744],
#  '1461': [5203],
#  '17846': [2052, 2794],
#  '5705': [2054],
#  '1465': [3109, 4865, 6327],
#  '40966': [3466],
#  '34235': [4631, 6294],
#  '50620': [3980],
#  '34237': [5096, 7036],
#  '17855': [1295, 5096],
#  '1474': [3656],
#  '1476': [3869],
#  '1478': [4978],
#  '1480': [4900],
#  '50633': [7779],
#  '33015': [5129],
#  '17868': [4004, 5346],
#  '50638': [827],
#  '34258': [4671],
#  '17876': [2493, 2666, 5015],
#  '34261': [1420, 1427],
#  '50649': [5148],
#  '17883': [106, 378],
#  '17884': [2372],
#  '17885': [2183, 2956],
#  '1502': [1715, 6539],
#  '34272': [5759],
#  '50657': [3478],
#  '34275': [3273, 3762, 5091],
#  '1510': [6327],
#  '16636': [4271],
#  '17898': [5038],
#  '2983': [1898, 2666],
#  '34284': [1953, 2657],
#  '22098': [475, 668],
#  '1518': [1885, 3590],
#  '1519': [2137],
#  '17904': [1430],
#  '52136': [320, 662],
#  '34291': [4069],
#  '1524': [5091],
#  '50677': [3483],
#  '50678': [3581, 3590],
#  '1527': [1848, 2932],
#  '50680': [3980, 7445],
#  '34297': [676, 1295, 6424],
#  '34299': [5171],
#  '50684': [365, 599],
#  '34302': [960],
#  '17920': [6150],
#  '17922': [968, 5211],
#  '50691': [7613],
#  '17924': [960, 1241, 1431, 2493],
#  '1542': [4985],
#  '17928': [3087, 3876],
#  '50697': [1295],
#  '34315': [355, 1427],
#  '17933': [3466],
#  '35757': [3980],
#  '17937': [1875, 3762],
#  '50707': [2612, 3763, 3872],
#  '50715': [275, 475, 830],
#  '34332': [6149],
#  '1568': [3656],
#  '17955': [5114],
#  '52972': [2794],
#  '34344': [3110],
#  '50730': [2050, 4701],
#  '49415': [2373, 5359],
#  '17964': [5351],
#  '35762': [3087, 3750],
#  '45880': [348, 5297],
#  '1585': [1381, 3412],
#  '1586': [2517],
#  '1589': [4631],
#  '35764': [3836],
#  '34363': [475, 1633],
#  '17982': [3679],
#  '17983': [5359, 6185],
#  '17984': [1, 2, 6, 11, 21, 24, 33, 50],
#  '50753': [378, 629],
#  '41228': [295, 446, 703, 960, 1005],
#  '1610': [2526],
#  '52151': [7604, 8852],
#  '34383': [2956],
#  '50774': [355, 446, 447],
#  '18007': [355, 1067],
#  '34392': [4407],
#  '34397': [1078, 1097],
#  '18017': [7869],
#  '1634': [320],
#  '34404': [360, 599, 760],
#  '34405': [6420],
#  '21877': [320, 359, 930, 1319],
#  '18027': [4865],
#  '1645': [359, 1067, 1171],
#  '18031': [1, 3, 5, 11, 21, 24, 25],
#  '50801': [1295],
#  '34418': [2203],
#  '41235': [4395],
#  '34423': [6327],
#  '1656': [668, 1005, 1524],
#  '1657': [1618],
#  '34426': [5308, 5364],
#  '1660': [5171, 7911],
#  '18045': [350, 446, 1431],
#  '1663': [6440],
#  '1665': [3087],
#  '18051': [1824, 2956],
#  '34436': [2122],
#  '18053': [355, 1381],
#  '34438': [3656],
#  '34439': [6759],
#  '1673': [2372],
#  '12668': [706, 1875, 3758],
#  '34443': [7053],
#  '1677': [343, 1319],
#  '18063': [2165],
#  '1683': [2794],
#  '18068': [703, 865, 1301],
#  '18069': [900],
#  '50838': [3304, 3467, 3763],
#  '50839': [1554, 1848, 2932],
#  '1689': [3304],
#  '34458': [3590, 5346],
#  '22127': [3110],
#  '18076': [2175, 2873, 3750],
#  '18077': [890, 1371],
#  '34464': [599, 760, 890, 1427],
#  '34471': [5246],
#  '1706': [3087, 4887],
#  '50864': [3304],
#  '53183': [475, 827],
#  '1714': [8600],
#  '50867': [3980],
#  '18100': [21, 24, 25, 50, 122, 431],
#  '24862': [5064],
#  '50871': [5043],
#  '1720': [3476],
#  '50873': [3412, 3682, 3805],
#  '34490': [1428, 4687],
#  '1724': [5114, 5526],
#  '50878': [6537],
#  '50880': [5246, 7624],
#  '1729': [2203, 2612],
#  '43979': [5015],
#  '50886': [5345],
#  '18119': [6149],
#  '18120': [968],
#  '1737': [662, 706, 760, 1319],
#  '13697': [1430, 3656],
#  '50898': [4004],
#  '19406': [2932, 4687],
#  '50905': [1911],
#  '1756': [6327],
#  '34525': [4008, 4662],
#  '1758': [1624],
#  '1759': [295, 320, 359],
#  '34529': [4069, 7733],
#  '1762': [6150],
#  '34531': [6, 475],
#  '1766': [1430],
#  '11217': [4687],
#  '34539': [1624, 2052],
#  '34542': [5345, 5755],
#  '13949': [5759],
#  '11219': [2794],
#  '1780': [1078],
#  '18166': [1625],
#  '35796': [8647],
#  '18172': [5544, 6671],
#  '1789': [2052],
#  '1790': [2054],
#  '52181': [5015, 5357],
#  '1792': [2165],
#  '1794': [1426, 3304],
#  '18179': [106, 249, 320],
#  '18182': [3869],
#  '1799': [446, 816],
#  '34568': [449, 2657],
#  '34570': [6192],
#  '34571': [656, 7613],
#  '34572': [1097, 1103],
#  '1813': [2998],
#  '34582': [2865],
#  '34583': [7035],
#  '1816': [7733],
#  '1824': [1845, 2203],
#  '34593': [2744],
#  '34594': [1427],
#  '18213': [4887, 5211],
#  '1831': [1845],
#  '18216': [5129, 7624],
#  '18217': [1078, 2156],
#  '36892': [4662, 7445],
#  '1837': [2137],
#  '18222': [3872],
#  '18224': [3008],
#  '34609': [3805],
#  '307': [870],
#  '18228': [355, 449, 475, 3711],
#  '1845': [2054, 2623],
#  '34614': [3977],
#  '50999': [13, 122, 456],
#  '8500': [2159],
#  '18237': [890, 2767],
#  '34623': [1875, 3763, 4407],
#  '18240': [706, 2052],
#  '19424': [1097, 3762],
#  '1859': [475, 830],
#  '18244': [3412],
#  '51013': [4264],
#  '1862': [4406],
#  '44001': [2657, 2666],
#  '13964': [2932],
#  '18254': [4978],
#  '46733': [3483],
#  '34641': [3679],
#  '1875': [6588],
#  '1883': [1591, 1715],
#  '49466': [1078],
#  '34656': [656, 1824],
#  '51043': [3102],
#  '51044': [5107, 7613],
#  '35814': [7745],
#  '51046': [656, 1852, 2050],
#  '1896': [1898, 4407],
#  '18281': [1911, 3109],
#  '34668': [6900],
#  ...}

# %%
user_interactions_test
# Out:
# {'49152': [1301, 2442, 3273, 4948, 7053],
#  '49154': [4407],
#  '27307': [5356],
#  '32773': [4671, 9419],
#  '7': [4588],
#  '32776': [6295],
#  '16402': [5129],
#  '16403': [2839, 7036],
#  '16404': [2373],
#  '16405': [9557],
#  '23': [9516],
#  '49179': [5659],
#  '18550': [1067, 1097, 5211, 5527],
#  '16415': [4395],
#  '49184': [6295, 6854, 9475],
#  '16417': [2199, 6310],
#  '32802': [5211],
#  '35': [4473],
#  '49188': [9557],
#  '16421': [1427, 3102],
#  '32807': [8745],
#  '32809': [1431],
#  '32810': [4395],
#  '32811': [9827],
#  '16429': [6531],
#  '49198': [6185],
#  '49203': [6671],
#  '49204': [8682],
#  '16441': [8765],
#  '21855': [7058, 7733],
#  '16445': [7214],
#  '32831': [3977],
#  '49216': [5148],
#  '16453': [5308],
#  '49222': [2054],
#  '32841': [2623, 6751],
#  '75': [4987],
#  '16460': [1554],
#  '32845': [4965],
#  '32848': [5113, 6419],
#  '16465': [5454],
#  '82': [5358],
#  '49236': [6538],
#  '32853': [7058],
#  '44739': [6969],
#  '32856': [5368],
#  '16473': [5357],
#  '32858': [7672],
#  '40975': [1885, 3698, 4271],
#  '16476': [4948, 5297, 6514, 7733],
#  '32865': [7996, 8694],
#  '49251': [1633, 3750],
#  '49254': [6531],
#  '32872': [1842],
#  '32876': [5351, 6656],
#  '49262': [7911, 8694],
#  '49263': [6327],
#  '16496': [4069],
#  '32885': [7909],
#  '49272': [9844],
#  '124': [4406],
#  '32894': [4980],
#  '49279': [6150],
#  '10944': [25, 67, 662, 930, 1202, 1319, 4865],
#  '49282': [3562, 4692],
#  '32900': [5359],
#  '133': [3711],
#  '35466': [7926, 8088],
#  '19137': [4820, 6693],
#  '32904': [7194],
#  '49289': [365, 431, 446, 668, 900, 1241, 1911],
#  '32906': [5755],
#  '32907': [4631, 5166, 5297, 9820],
#  '49295': [365, 378, 431, 446, 668, 900, 1241, 1911],
#  '49297': [365, 378, 431, 446, 668, 900, 1241, 1911],
#  '16530': [7869],
#  '49299': [4985, 5351, 6531, 9532],
#  '32916': [930, 1202, 4692, 5527],
#  '46446': [5308],
#  '32918': [33, 34, 447, 760, 865, 6192],
#  '153': [7244],
#  '32923': [67, 320, 348, 359, 6185, 8698],
#  '49308': [7437],
#  '16541': [1431],
#  '158': [1885, 4271],
#  '16543': [5527],
#  '32929': [5357],
#  '16550': [6858],
#  '32937': [7661],
#  '32938': [9865],
#  '32940': [7869],
#  '173': [320, 357],
#  '32943': [5113],
#  '49329': [1420, 2175],
#  '178': [930, 3103],
#  '16564': [8088],
#  '49333': [6693],
#  '32951': [4138],
#  '32952': [1430],
#  '16569': [33, 320, 357, 360, 3711],
#  '16573': [1622, 1885, 2052],
#  '16575': [5113],
#  '49344': [8073],
#  '16577': [5359],
#  '32962': [5246, 9844],
#  '21878': [7779],
#  '40993': [2054],
#  '202': [4004],
#  '16587': [3483, 4588, 5357, 6440],
#  '204': [9516],
#  '206': [9998],
#  '207': [5211],
#  '213': [3867],
#  '215': [3974],
#  '16600': [7624],
#  '218': [8600],
#  '16603': [5096, 5197, 7445],
#  '32990': [6514],
#  '8229': [2998],
#  '16609': [8698],
#  '32994': [5454],
#  '16612': [9419],
#  '16614': [5038],
#  '16618': [5168],
#  '16621': [9646],
#  '13693': [8073, 9592],
#  '244': [7603],
#  '49397': [4934, 6138],
#  '41': [1934],
#  '16634': [7053],
#  '251': [5826],
#  '252': [8600],
#  '16637': [5349],
#  '19157': [5954],
#  '256': [2054],
#  '16642': [1431],
#  '49412': [5907],
#  '16647': [7199],
#  '16652': [9820],
#  '33037': [1842],
#  '16656': [4980],
#  '33041': [5805],
#  '274': [816, 1319],
#  '16662': [2493, 5203],
#  '33047': [7053],
#  '16664': [8765],
#  '33049': [4271],
#  '16668': [6539],
#  '33053': [7911, 7996, 8694],
#  '33054': [8765],
#  '287': [5439],
#  '16672': [9820],
#  '289': [9539],
#  '16675': [2137],
#  '33065': [33, 50, 93, 106, 357, 378, 1633, 1845],
#  '33068': [6424],
#  '33069': [5439],
#  '33074': [7672],
#  '33075': [976, 6539],
#  '21497': [8337],
#  '16694': [5872],
#  '314': [343, 348, 760, 976, 2054],
#  '21818': [7733],
#  '33085': [2794],
#  '16703': [5659],
#  '321': [2794],
#  '49474': [8852],
#  '324': [2657],
#  '41014': [6656],
#  '16711': [7733],
#  '13708': [9777],
#  '33100': [8073],
#  '16717': [9530],
#  '33102': [4985],
#  '16720': [7624],
#  '33105': [5954],
#  '49491': [2666, 3698, 9530],
#  '341': [4069],
#  '33110': [4934, 7588],
#  '343': [4631, 8765],
#  '14196': [3636],
#  '5467': [2657],
#  '349': [3869, 5346],
#  '16735': [7081, 7728],
#  '356': [5203],
#  '33127': [2547, 6858],
#  '16744': [6693],
#  '49514': [865, 1427],
#  '363': [2054, 3876],
#  '16749': [7613],
#  '366': [5187],
#  '49519': [7728],
#  '33136': [3467],
#  '49523': [5805],
#  '16757': [3805],
#  '376': [4806],
#  '33147': [865, 998, 1319, 1426, 1842, 3805, 5043],
#  '381': [7728],
#  '16769': [9913],
#  '16770': [4982, 5187],
#  '49540': [3867, 4687, 4978, 6541],
#  '13718': [5148],
#  '49543': [5246, 7194],
#  '43756': [8765],
#  '49547': [9530],
#  '8258': [1524, 5527],
#  '16782': [5351, 6514],
#  '400': [3805],
#  '13720': [6671],
#  '33170': [5246, 7445],
#  '16789': [5203],
#  '49559': [6858],
#  '16793': [4948],
#  '49564': [2794],
#  '49566': [8852],
#  '41029': [5114, 5351],
#  '27376': [5297],
#  '16804': [9777],
#  '49573': [870, 2666],
#  '33191': [3273],
#  '424': [475, 976],
#  '426': [6588],
#  '33203': [3977],
#  '33204': [6853],
#  '16821': [6334],
#  '16822': [9777],
#  '33207': [930, 2517],
#  '16827': [4806],
#  '33212': [4701],
#  '16829': [3466],
#  '446': [1842, 2049],
#  '447': [5526, 6427],
#  '33216': [3110],
#  '48776': [4985],
#  '451': [6628],
#  '454': [8337],
#  '16841': [4069],
#  '33227': [4796],
#  '461': [7199],
#  '16848': [880, 7926],
#  '466': [6310],
#  '33237': [9913],
#  '33241': [6427],
#  '16859': [2054],
#  '476': [4965],
#  '33245': [6751],
#  '16464': [9998],
#  '33250': [7672],
#  '49635': [3473, 6531],
#  '49636': [355],
#  '16870': [8921],
#  '487': [4965],
#  '16873': [9844],
#  '491': [8127, 8600],
#  '16876': [5187],
#  '16466': [3581, 3590],
#  '494': [6327],
#  '49651': [7815],
#  '16884': [9419],
#  '33269': [5413],
#  '13737': [2547, 5113],
#  '33272': [4980],
#  '24117': [7996],
#  '27295': [5190],
#  '49661': [2493, 2517],
#  '49663': [8698],
#  '513': [5114, 6334],
#  '13739': [4965, 6588],
#  '33285': [7144],
#  '519': [4137],
#  '16904': [4069],
#  '49673': [7926, 9517],
#  '33293': [5368],
#  '33296': [9592],
#  '16913': [93, 122, 355, 475, 656, 1622, 3008, 3711],
#  '33298': [1427],
#  '16915': [4796],
#  '46510': [9777],
#  '49688': [7996, 8694],
#  '48573': [6693],
#  '16922': [5096],
#  '33307': [3483, 4806, 5093],
#  '27398': [4004, 5358],
#  '49703': [5755],
#  '52938': [5349],
#  '33322': [8172],
#  '33323': [8694],
#  '557': [5805, 9777],
#  '33326': [1554],
#  '13112': [2049, 5527],
#  '33328': [9590, 9998],
#  '16945': [6628, 9301],
#  '33337': [1848, 6419],
#  '16955': [6288],
#  '573': [4965],
#  '33343': [9820],
#  '49733': [5211, 6420],
#  '16970': [5113],
#  '46519': [6588],
#  '588': [67, 122, 249, 320, 378, 446, 662, 4630],
#  '589': [930, 1715, 3679],
#  '15841': [7244],
#  '49749': [7604],
#  '16982': [7624],
#  '13753': [6185],
#  '49752': [2122, 2199, 2932, 3711],
#  '606': [7126, 7733],
#  '33378': [5357],
#  '21947': [7081],
#  '16996': [7445],
#  '32870': [9865],
#  '49766': [5113],
#  '6878': [6425],
#  '33384': [6853],
#  '33390': [7214],
#  '17009': [3805],
#  '17013': [3977],
#  '49783': [4701],
#  '17017': [4965],
#  '17018': [5358],
#  '33403': [7745],
#  '17020': [5171],
#  '49790': [7437],
#  '43797': [3466],
#  '33409': [1426, 1427, 4271],
#  '2838': [1885],
#  '33417': [4887, 5358],
#  '17039': [5368],
#  '657': [7604],
#  '17044': [6858],
#  '8302': [706, 2199],
#  '17051': [5805],
#  '17052': [5454],
#  '49823': [4980],
#  '33440': [5439],
#  '29832': [5349],
#  '676': [6327],
#  '33445': [6656],
#  '49830': [475, 865, 998],
#  '33450': [3476],
#  '33454': [4662],
#  '33455': [1431, 4692, 6751],
#  '17073': [3758],
#  '690': [6138],
#  '49843': [5470],
#  '17078': [3102],
#  '17080': [9539],
#  '17081': [5351],
#  '49850': [1953],
#  '33467': [8698],
#  '17086': [4806],
#  '33471': [6656],
#  '17088': [4954],
#  '33473': [4137, 4865, 5349],
#  '33474': [7199],
#  '712': [4473],
#  '38348': [5872, 7588],
#  '49867': [7745],
#  '33484': [8745],
#  '35618': [1885, 2623],
#  '17104': [6759, 7624],
#  '17105': [357, 360, 662],
#  '725': [320, 668, 1427, 1845],
#  '726': [6327],
#  '33497': [7332],
#  '17114': [6295],
#  '732': [3867],
#  '17117': [6526],
#  '49886': [5168, 7214],
#  '33503': [4954, 7624],
#  '736': [3581],
#  '49889': [5659],
#  '8315': [5038],
#  '33509': [7926],
#  '17127': [8908],
#  '8316': [6138],
#  '17130': [6858],
#  '52007': [865, 1427, 1845],
#  '33516': [5932],
#  '17135': [9516],
#  '33522': [7604],
#  '8318': [9516],
#  '33527': [865, 1319, 3467],
#  '17144': [7723],
#  '762': [5509],
#  '17148': [6538],
#  '766': [7053],
#  '17157': [7926],
#  '33546': [5296],
#  '33547': [2657],
#  '49934': [7081, 7728],
#  '49935': [8337],
#  '33555': [4271, 5351, 5872],
#  '33556': [2049, 5114],
#  '33557': [3869],
#  '49942': [5907],
#  '33560': [3368],
#  '17177': [4894],
#  '49947': [6854],
#  '797': [3869],
#  '33567': [5872],
#  '800': [6753],
#  '19248': [3466, 6539],
#  '17189': [7053],
#  '14408': [5805],
#  '17193': [4271],
#  '33580': [4004],
#  '19250': [1715],
#  '33582': [9820],
#  '17199': [3869],
#  '49968': [7745],
#  '33585': [8908, 9777],
#  '17203': [7058],
#  '49972': [6149],
#  '49973': [6419],
#  '17207': [6425],
#  '49976': [6295],
#  '49978': [5472, 8765, 9592, 9827],
#  '827': [5297],
#  '828': [4894, 4989],
#  '49982': [8172],
#  '33599': [830, 1295, 4954, 7745],
#  '17216': [2156, 4004],
#  '836': [7199],
#  '33606': [9804],
#  '17224': [7058],
#  '33609': [5357, 5470],
#  '11063': [4138, 5107],
#  '17228': [890, 1591, 1622, 1885, 3679],
#  '49998': [1885],
#  '33615': [6425],
#  '33616': [4978],
#  '849': [5932],
#  '50002': [5356, 7728],
#  '49129': [5805],
#  '33621': [3698],
#  '854': [6854, 6858],
#  '17239': [8127],
#  '856': [7603],
#  '33625': [4806, 5203],
#  '858': [3590],
#  '17243': [8600],
#  '33632': [9301],
#  '33633': [1633, 6440],
#  '50022': [6526],
#  '50023': [5907, 8127],
#  '14954': [6420],
#  '873': [7432],
#  '33642': [7437, 8172, 8852],
#  '49298': [93, 706, 1431, 1625, 2794, 7714],
#  '46568': [6671],
#  '883': [2052],
#  '17269': [4900],
#  '17270': [5308],
#  '33655': [5659, 7445],
#  '50040': [6295],
#  '889': [4407],
#  '33662': [6514, 9557],
#  '895': [4138, 5357],
#  '33665': [6541],
#  '17282': [4980],
#  '17285': [4671],
#  '50055': [7815, 9913],
#  '907': [5346],
#  '17292': [5364],
#  '33677': [8694],
#  '33679': [6440],
#  '50064': [5472],
#  '50065': [5872],
#  '17300': [7714],
#  '50069': [6588],
#  '8345': [4138],
#  '17304': [5755],
#  '19268': [6751],
#  '922': [4887],
#  '923': [6440, 7603],
#  '12663': [7604],
#  '17310': [8921],
#  '33697': [28, 29, 50, 599, 890, 1554],
#  '931': [1911, 5349],
#  '17316': [3872, 6526, 9557],
#  '50085': [7624],
#  '33704': [6759],
#  '50089': [7714],
#  '17322': [5368],
#  '17323': [7967],
#  '50094': [6671],
#  '943': [5364],
#  '33712': [7244],
#  '33713': [3483, 3636, 7244],
#  '946': [930, 5349],
#  '50100': [6628],
#  '33717': [5454],
#  '50102': [365, 431, 446, 668, 830, 900],
#  '951': [456, 599, 1624, 2199, 5358],
#  '50104': [106, 348, 360, 365, 431, 446, 668, 830, 900, 6748],
#  '22004': [9844],
#  '33723': [5351],
#  '958': [5526],
#  '17343': [5297, 5364],
#  '33728': [5186],
#  '965': [9712],
#  '50119': [2049, 6751],
#  '33736': [8852],
#  '33739': [7053],
#  '17356': [5148],
#  '973': [9998],
#  '17359': [3805],
#  '17360': [7613],
#  '17361': [6440],
#  '50130': [4138, 5186],
#  '50133': [360, 365, 431, 446, 668, 830, 900, 1371],
#  '50137': [5091],
#  '50141': [9865],
#  '17375': [6751],
#  '994': [7126],
#  '33763': [7445],
#  '33764': [4806, 5129],
#  '997': [2873, 4004, 5826],
#  '35665': [7613],
#  '17385': [7672],
#  '1002': [7214],
#  '33772': [4806],
#  '1005': [6419],
#  '50158': [4137],
#  '22013': [5357, 5805],
#  '17392': [4953],
#  '33777': [5470],
#  '52051': [2137, 6538],
#  '46590': [6759, 8909],
#  '1014': [4138],
#  '41129': [6708],
#  '1017': [4900],
#  '1019': [668],
#  '17404': [3758],
#  '17405': [456, 1103, 2547, 6294],
#  '1022': [6538],
#  '33792': [3763],
#  '17418': [2054, 5171, 8694],
#  '19287': [9820],
#  '47907': [9777],
#  '1037': [4887, 4965],
#  '1038': [1911],
#  '50191': [6424],
#  '1041': [2767],
#  '8218': [4820, 4989, 5544],
#  '33815': [5509, 5527],
#  '50200': [3483],
#  '50202': [8694],
#  '49327': [6628],
#  '50204': [7779, 8695],
#  '50205': [5659],
#  '17438': [3836],
#  '17440': [2052],
#  '1057': [4004],
#  '1059': [6628],
#  '17446': [9998],
#  '1064': [6138],
#  '17450': [6588],
#  '33836': [6334],
#  '33838': [5349],
#  '1072': [9475, 9592],
#  '17458': [2612],
#  '15857': [2547, 9475],
#  '1078': [6138],
#  '1081': [5349],
#  '1084': [6327],
#  '16565': [6138],
#  '33856': [7733],
#  '33858': [1524],
#  '17475': [2657, 3273, 5171],
#  '50244': [9557],
#  '50247': [5872],
#  '33864': [365, 599, 816, 1633, 2998],
#  '16567': [7714],
#  '17485': [8600],
#  '33872': [93, 378, 1202, 1845],
#  '50258': [2517, 4692],
#  '33875': [5755],
#  '1108': [9516],
#  '33877': [7053],
#  '50262': [5186],
#  '1115': [3581, 3590, 4004, 4865],
#  '17502': [5439],
#  '1119': [5470],
#  '33890': [357, 431, 1301, 2203],
#  '17507': [9419],
#  '50277': [7244],
#  '50279': [7745],
#  '33896': [3679],
#  '33902': [6854],
#  '17519': [6708],
#  '1136': [890, 960, 2156],
#  '50289': [1934, 5544],
#  '17522': [9648],
#  '50291': [4985, 5114],
#  '1140': [7613],
#  '17525': [4339],
#  '19305': [6751],
#  '1144': [5454],
#  '38420': [4671],
#  '1146': [7909],
#  '32959': [9557],
#  '3857': [6192],
#  '46505': [7805, 9844],
#  '33922': [6759],
#  '50309': [6334],
#  '50313': [4978, 4985, 5203, 5805],
#  '50315': [2873, 3562],
#  '17548': [8648],
#  '50317': [5113],
#  '1167': [4985],
#  '17552': [8088],
#  '1169': [29, 33, 50, 93, 1005, 2049, 5346],
#  '17554': [3473],
#  '17555': [3008, 5526],
#  '50325': [2998],
#  '50326': [5479],
#  '17559': [6751],
#  '33945': [2050],
#  '1182': [4671],
#  '17568': [2932, 4934, 6138],
#  '1185': [599, 662, 1319, 6334],
#  '1187': [5043],
#  '50340': [6526],
#  '17574': [4980],
#  '33964': [6689],
#  '1198': [5359],
#  '33969': [4989, 5166],
#  '50358': [6671],
#  '1207': [6854],
#  '32970': [4980],
#  '33982': [4008],
#  '33983': [8694],
#  '33984': [6295],
#  '1221': [6440],
#  '33993': [2612],
#  '33994': [5509],
#  '33996': [5544, 7745],
#  '17613': [3985],
#  '17614': [7604],
#  '17617': [3109, 5358],
#  '17618': [7332],
#  '22051': [5168],
#  '50388': [3476],
#  '34008': [5096, 5190, 5246],
#  '1241': [4069],
#  '34011': [5470, 6440],
#  '1245': [5805],
#  '34014': [4865],
#  '50399': [865, 890, 2493],
#  '17633': [3590],
#  '34018': [6656],
#  '43899': [5826],
#  '34020': [6759],
#  '1255': [5187],
#  '1256': [6327],
#  '34026': [7214],
#  '17643': [703, 706, 865, 1301, 1427, 1953],
#  '1263': [9590],
#  '1266': [4631],
#  '17652': [5345, 5755, 9416],
#  '1269': [9777],
#  '17654': [6420],
#  '34039': [5509],
#  '1277': [9532],
#  '1278': [5526],
#  '17663': [976, 998, 1875, 2049, 3698, 5351, 6427],
#  '1280': [5364, 9592],
#  '17665': [930],
#  '17666': [8909],
#  '34051': [5187],
#  '1285': [4887],
#  '1286': [1898],
#  '1289': [5349],
#  '50442': [6541],
#  '1291': [4687, 4965],
#  '50444': [4806, 5203, 7244],
#  '1294': [1430],
#  '1296': [930, 5413],
#  '49368': [4952, 4985],
#  '34066': [3466],
#  '17683': [3711],
#  '34072': [5359],
#  '17690': [9516],
#  '1307': [1232, 2623],
#  '34077': [2623],
#  '34078': [5091],
#  '34079': [3763],
#  '34083': [1420, 4339, 6425],
#  '1317': [8909],
#  '1318': [5349],
#  '17703': [2744],
#  '17704': [3836],
#  '1323': [1319, 3304],
#  '50478': [9648],
#  '13875': [7613],
#  '50485': [6150],
#  '17718': [3763, 4671],
#  '19337': [7126],
#  '14229': [3412],
#  '1339': [6751],
#  '1340': [8127],
#  '34111': [7126],
#  '50498': [9517],
#  '50499': [5190],
#  '34116': [7805],
#  '34118': [5544],
#  '17735': [5544],
#  '1353': [4138],
#  '50506': [7061, 7815],
#  '1355': [3102, 6531],
#  '1357': [7603],
#  '34126': [6424],
#  '1359': [5246],
#  '50514': [4980],
#  '50515': [7445, 8852],
#  '1364': [6753],
#  '34135': [5096, 8909],
#  '50521': [6514],
#  '1370': [4630],
#  '1374': [1885],
#  '1377': [2165, 3656],
#  '34147': [2373, 5359, 7763],
#  '34148': [9712],
#  '1381': [5932],
#  '17766': [4796],
#  '1383': [4631],
#  '34152': [3985],
#  '46652': [5356],
#  '1391': [2865],
#  '1393': [5932],
#  '13886': [4865],
#  '41193': [2137],
#  '1401': [8698],
#  '1402': [7061],
#  '5695': [3273, 6192],
#  '34172': [8682],
#  '17789': [2156],
#  '1407': [4887],
#  '50560': [7815],
#  '50562': [4985],
#  '1411': [5826],
#  '17796': [5113],
#  '17800': [5346],
#  '17801': [2175],
#  '17802': [7081],
#  '34187': [5190],
#  '17804': [960, 3698],
#  '34189': [5349],
#  '1423': [9777],
#  '34192': [6867],
#  '34193': [1427, 3103],
#  '1428': [3985, 7199],
#  '1429': [1171, 2880],
#  '50582': [760, 1591, 4271],
#  '50584': [6671],
#  '17817': [5186],
#  '17819': [5197],
#  '34205': [7728],
#  '34208': [6537],
#  '50593': [3758, 4138, 5203, 7728],
#  '34211': [5197, 7061],
#  '17832': [976, 1898, 3869],
#  '1449': [1845, 3412, 9516],
#  '50602': [7053],
#  '17835': [9419],
#  '50604': [7714],
#  '1456': [760, 1005, 1078],
#  '46664': [5357],
#  '50610': [599, 760, 1005],
#  '50612': [5526],
#  '1461': [6858],
#  '17846': [5356],
#  '5705': [6588],
#  '1465': [6440, 8127],
#  '40966': [7733],
#  '34235': [9416],
#  '50620': [6759],
#  '34237': [7194],
#  '17855': [5190, 6759],
#  '1474': [6539],
#  '1476': [4473],
#  '1478': [7603],
#  '1480': [5954],
#  '50633': [7779],
#  '33015': [5826],
#  '17868': [7603],
#  '50638': [4407],
#  '34258': [9328],
#  '17876': [5357, 6440],
#  '34261': [2156],
#  '50649': [5345],
#  '17883': [662, 4671],
#  '17884': [2373],
#  '17885': [5171, 7624],
#  '1502': [7779],
#  '34272': [6531],
#  '50657': [6541],
#  '34275': [6858, 8694],
#  '1510': [6748],
#  '16636': [4407],
#  '17898': [8695],
#  '2983': [5093],
#  '34284': [4701],
#  '22098': [7432, 9516],
#  '1518': [4671],
#  '1519': [7603],
#  '17904': [2165],
#  '52136': [2049],
#  '34291': [5439],
#  '1524': [8600],
#  '50677': [5015],
#  '50678': [4271, 7723],
#  '1527': [5345],
#  '50680': [8852],
#  '34297': [7745, 8852],
#  '34299': [7058],
#  '50684': [760, 4806],
#  '34302': [1624],
#  '17920': [7604],
#  '17922': [5479, 7714],
#  '50691': [9844],
#  '17924': [3478, 5168, 7082],
#  '1542': [6753],
#  '17928': [4934, 5166],
#  '50697': [2183],
#  '34315': [7082],
#  '17933': [5091],
#  '35757': [4929],
#  '17937': [5351, 9557],
#  '50707': [4671, 5187, 5358],
#  '50715': [2183, 3008, 7437],
#  '34332': [8682],
#  '1568': [5349],
#  '17955': [5171],
#  '52972': [7624],
#  '34344': [3977],
#  '50730': [5759, 8172],
#  '49415': [7604],
#  '17964': [6708],
#  '35762': [6854],
#  '45880': [6425],
#  '1585': [5826],
#  '1586': [5932],
#  '1589': [8765],
#  '35764': [6310],
#  '34363': [2199],
#  '17982': [5346],
#  '17983': [6539, 7126],
#  '17984': [67, 93, 106, 343, 359, 1241, 1301, 3805],
#  '50753': [5932, 6867],
#  '41228': [1319, 1715, 3869, 4271],
#  '1610': [8647],
#  '52151': [9844],
#  '34383': [7081],
#  '50774': [2623, 4339, 8695],
#  '18007': [1232, 2199],
#  '34392': [5094],
#  '34397': [1371],
#  '18017': [8953],
#  '1634': [6588],
#  '34404': [1381, 1591, 4985],
#  '34405': [7058],
#  '21877': [1715, 3763, 5454],
#  '18027': [6588],
#  '1645': [1232, 8600],
#  '18031': [33, 67, 122, 295, 703, 1618],
#  '50801': [2183],
#  '34418': [5351],
#  '41235': [8073],
#  '34423': [6693],
#  '1656': [5932, 8073],
#  '1657': [3412],
#  '34426': [9419],
#  '1660': [7996, 8694],
#  '18045': [1953, 4588, 5358],
#  '1663': [7214],
#  '1665': [5166],
#  '18051': [5759, 7926],
#  '34436': [5308],
#  '18053': [1953, 3711],
#  '34438': [5872],
#  '34439': [6900],
#  '1673': [6185],
#  '12668': [4965, 6334, 6427],
#  '34443': [9475],
#  '1677': [3273, 3876],
#  '18063': [3102],
#  '1683': [3581],
#  '18068': [1715, 2657, 4887],
#  '18069': [7723],
#  '50838': [3876, 6427],
#  '50839': [4985, 5755, 5805],
#  '1689': [6425],
#  '34458': [6751],
#  '22127': [9303],
#  '18076': [5113, 5470, 6185],
#  '18077': [6288],
#  '34464': [1591, 2156, 2873],
#  '34471': [6424],
#  '1706': [6288],
#  '50864': [6427],
#  '53183': [830, 1295],
#  '1714': [9648],
#  '50867': [4929],
#  '18100': [446, 976, 1845, 2052, 2199, 3758],
#  '24862': [7445],
#  '50871': [9717],
#  '1720': [6693],
#  '50873': [5043, 8647],
#  '34490': [4952],
#  '1724': [6420],
#  '50878': [9532],
#  '50880': [8852],
#  '1729': [5826],
#  '43979': [5357],
#  '50886': [5659],
#  '18119': [9590],
#  '18120': [6751],
#  '1737': [1845, 2612, 5527],
#  '13697': [7763],
#  '50898': [9532],
#  '19406': [5345, 5755],
#  '50905': [2137],
#  '1756': [6526],
#  '34525': [4929, 5190],
#  '1758': [4138],
#  '1759': [431, 668],
#  '34529': [8337],
#  '1762': [7603],
#  '34531': [629],
#  '1766': [2165],
#  '11217': [5107],
#  '34539': [3590],
#  '34542': [5805],
#  '13949': [6531],
#  '11219': [7624],
#  '1780': [4887],
#  '18166': [2794],
#  '35796': [9648],
#  '18172': [7437],
#  '1789': [3476],
#  '1790': [3656],
#  '52181': [5470],
#  '1792': [5166],
#  '1794': [6334],
#  '18179': [378, 1911, 5187],
#  '18182': [7805],
#  '1799': [1624],
#  '34568': [5659, 6539],
#  '34570': [6541],
#  '34571': [7714, 7745],
#  '34572': [5129, 7733],
#  '1813': [8909],
#  '34582': [5114],
#  '34583': [9777],
#  '1816': [8337],
#  '1824': [3685, 6588],
#  '34593': [5368],
#  '34594': [1591],
#  '18213': [5932],
#  '1831': [3109],
#  '18216': [7733],
#  '18217': [2873, 3476],
#  '36892': [8852],
#  '1837': [5346],
#  '18222': [9820],
#  '18224': [7332],
#  '34609': [4887],
#  '307': [4887],
#  '18228': [4954, 5759, 9844],
#  '1845': [6192],
#  '34614': [8172],
#  '50999': [676, 1633, 1845],
#  '8500': [2372],
#  '18237': [3110],
#  '34623': [4671, 6514],
#  '18240': [2156],
#  '19424': [6334, 6420],
#  '1859': [5308],
#  '18244': [3985],
#  '51013': [4980],
#  '1862': [7244],
#  '44001': [3876],
#  '13964': [5345],
#  '18254': [5356],
#  '46733': [3636],
#  '34641': [3762],
#  '1875': [9516],
#  '1883': [2865, 3805],
#  '49466': [4671],
#  '34656': [5130],
#  '51043': [7432],
#  '51044': [9844],
#  '35814': [7805],
#  '51046': [2122, 5755],
#  '1896': [4631, 4934],
#  '18281': [3467, 7053],
#  '34668': [7036],
#  ...}

# %%
# dict index 2 book id and vice-versa for recommendation 
idx2bookid = {i: id_ for i, id_ in enumerate(df_books.book_id)}
bookid2idx = {id_:i for i, id_ in enumerate(df_books.book_id)}

# %% [markdown]
# # Cargar características pre-entrenadas: BERT y BERT-large
#
# En esta sección se trabajará con modelos pre-entrenados de modelos de lenguage BERT y BERT-large que convierten texto a embeddings.
#
# Bidirectional Encoder Representations from Transformers (BERT) es una técnica de NLP (Natural Language Processing) desarrollada por Google y publicada en 2018 por Jacob Devlin.
#
# Actualmente Google utiliza BERT para entender las consultas de los usuarios en su buscador.
#
# Tiene dos versiones:
# - **BERT:** 12 capas, 12 cabezales de atencion y 110 millones de parámetros. Genera vectores de 768 dimensiones
# - **BERT-large:** 24 capas, 16 cabezales de atencion y 340 millones de parámetros.
#
# ![BERT y BERT-large](http://jalammar.github.io/images/bert-base-bert-large.png)
#
# ![BERT y BERT-large arquitectura](http://jalammar.github.io/images/bert-base-bert-large-encoders.png)
#
# En este caso los textos que utilizaremos son los títulos de los libros con su descripción y compararemos los resultados de recomendación con BERT y BERT-large. Para efectos de este trabajo los vectores de características ya fueron entrenados y guardados en archivos numpy. A continuación son cargados en memoria.
#
# Para mayores detalles sobre el modelo de lenguaje BERT se recomienda revisar el siguiente artículo:
# - [BERT: Pre-training of Deep Bidirectional Transformers for Language Understanding](https://arxiv.org/pdf/1810.04805.pdf)

# %%
bert_featmat = np.load('goodreads_bert_embeddings.npy', allow_pickle=True)
bert_large_featmat = np.load('goodreads_bert_large_embeddings.npy', allow_pickle=True)

# %%
bert_featmat.shape
# Out:
# (4771, 768)

# %%
bert_large_featmat.shape
# Out:
# (4771, 1024)

# %% [markdown]
# ### **Pregunta 1**
#
# Considerando que haremos un recomendador basado en contenidos ¿Por qué el uso de modelos de lenguage es una buena elección para este tipo de problema?

# %% [markdown]
# **Respuesta 1:**

# %% [markdown]
# # Probamos con BERT y BERT-large reduciendo dimensionalidad con PCA-20
#
# Una vez calculado (o cargado) los vectores característicos de cada libro a partir de su titulo y descripción, reducimos dimensionalidad. Probaremos con BERT y BERT-large para comparar los resultados de ambos en recomendación basada en contenido.

# %%
# Project into a 20 PCA feature space
pca20_bert_featmat = PCA(n_components=20).fit_transform(bert_featmat)
pca20_bert_large_featmat = PCA(n_components=20).fit_transform(bert_large_featmat)

# %%
pca20_bert_featmat.shape
# Out:
# (4771, 20)

# %%
pca20_bert_large_featmat.shape
# Out:
# (4771, 20)

# %% [markdown]
# ### **Pregunta 2**
#
# Comente por qué se utiliza PCA para reducir la dimensión de cada vector característico. ¿Qué sucede con la pérdida de información en la reducción de dimensionalidad?

# %% [markdown]
# ### Respuesta 2:

# %% [markdown]
# # Similar document retrieval
#
# En esta sección utilizaremos los vectores cargados para hacer un sistema de recuperación o búsqueda de información, para diferentes métricas de distancia.
#
# Buscamos libros similares de acuerdo a la representación vectorial (BERT) de su título y descripción.

# %%
# format results 
pd.options.display.max_colwidth = 50
pd.set_option('display.max_colwidth', -1)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# Find similar images by image id
def find_similar_books(embedding, query_id=None, metric='euclidean', topk=10):
    
    n = embedding.shape[0]
    
    if query_id is None:
        query_i = np.random.randint(n)
        query_id = idx2bookid[query_i]
    
    else:
        query_i = bookid2idx[query_id]
        
    
    distances = pairwise_distances(embedding[query_i].reshape(1,-1), embedding, metric=metric)
    heap = []
    for i in range(n):            
        if len(heap) < topk:
            heapq.heappush(heap, (-distances[0][i], i))
        else:
            heapq.heappushpop(heap, (-distances[0][i], i))

    heap.sort(reverse=True)
    rec_ids = [idx2bookid[i] for _,i in heap]
    
    return rec_ids

# %% [markdown]
# ## Usando BERT

# %%
# libros similares al libro de id 41865 (Twilight) utilizando distancia euclideana. se puede cambiar a "cosine" 
similar_books = find_similar_books(bert_featmat, query_id = 41865, metric = 'euclidean', topk=10 )
similar_books
# Out:
# [41865,
#  7617119,
#  8130839,
#  15799166,
#  7896345,
#  7187395,
#  395871,
#  13522285,
#  20797535,
#  6933876]

# %%
df_books[df_books.book_id.isin(similar_books)][['book_id', 'original_title', 'book_description', 'authors']]
# Out:
#        book_id  ...             authors
# 2     41865     ...  Stephenie Meyer
# 1383  395871    ...  L.J. Smith
# 1447  15799166  ...  J. Kenner
# 2044  13522285  ...  Robyn Schneider
# 2103  7896345   ...  Kelley Armstrong
# 3260  7187395   ...  Richard Paul Evans
# 3299  6933876   ...  Gail Carriger
# 3321  7617119   ...  Dan Wells
# 3411  8130839   ...  Andrea Cremer
# 4164  20797535  ...  Marcus Sakey
#
# [10 rows x 4 columns]

# %% [markdown]
# ## Usando BERT reducidos con PCA

# %%
# libros similares al libro de id 41865 (Twilight) utilizando distancia euclideana. se puede cambiar a "cosine" 
similar_books = find_similar_books(pca20_bert_featmat, query_id = 41865, metric = 'euclidean', topk=10 )
similar_books
# Out:
# [41865,
#  13522285,
#  5776788,
#  8130839,
#  7617119,
#  6455256,
#  1295102,
#  140671,
#  6368611,
#  9975679]

# %%
df_books[df_books.book_id.isin(similar_books)][['book_id', 'original_title', 'book_description', 'authors']]
# Out:
#        book_id  ...                            authors
# 2     41865     ...  Stephenie Meyer
# 723   1295102   ...  Sarah Dessen
# 2044  13522285  ...  Robyn Schneider
# 2487  140671    ...  Glen Cook
# 2752  5776788   ...  Richard Kadrey
# 2862  6368611   ...  Melissa Marr
# 3321  7617119   ...  Dan Wells
# 3411  8130839   ...  Andrea Cremer
# 3558  6455256   ...  James Patterson, Michael Ledwidge
# 3577  9975679   ...  Ilsa J. Bick
#
# [10 rows x 4 columns]

# %% [markdown]
# ## Usando BERT-large

# %%
# libros similares al libro de id 41865 (Twilight) utilizando distancia euclideana. se puede cambiar a "cosine" 
similar_books = find_similar_books(bert_large_featmat, query_id = 41865, metric = 'euclidean', topk=10 )
similar_books
# Out:
# [41865,
#  22611920,
#  15799166,
#  6303733,
#  17675462,
#  454856,
#  7783191,
#  18594594,
#  13188676,
#  13568619]

# %%
df_books[df_books.book_id.isin(similar_books)][['book_id', 'original_title', 'book_description', 'authors']]
# Out:
#        book_id  ...                             authors
# 2     41865     ...  Stephenie Meyer
# 794   17675462  ...  Maggie Stiefvater
# 1296  13188676  ...  Tahereh Mafi
# 1409  454856    ...  John Elder Robison
# 1447  15799166  ...  J. Kenner
# 3128  22611920  ...  Kristen Callihan
# 4255  18594594  ...  Karin Slaughter
# 4285  6303733   ...  Richard Russo, Arthur Morey
# 4347  7783191   ...  Christopher Chabris, Daniel Simons
# 4531  13568619  ...  Cassandra Clare, Joshua Lewis
#
# [10 rows x 4 columns]

# %% [markdown]
# ## Usando BERT-large reducidos con PCA

# %%
# libros similares al libro de id 41865 (Twilight) utilizando distancia euclideana. se puede cambiar a "cosine" 
similar_books = find_similar_books(pca20_bert_large_featmat, query_id = 41865, metric = 'euclidean', topk=10 )
similar_books
# Out:
# [41865,
#  22611920,
#  15799166,
#  18126198,
#  13188676,
#  6303733,
#  17411703,
#  17623975,
#  18594594,
#  38333]

# %%
df_books[df_books.book_id.isin(similar_books)][['book_id', 'original_title', 'book_description', 'authors']]
# Out:
#        book_id  ...                      authors
# 2     41865     ...  Stephenie Meyer
# 885   18126198  ...  Veronica Roth
# 1296  13188676  ...  Tahereh Mafi
# 1416  17623975  ...  Gayle Forman
# 1447  15799166  ...  J. Kenner
# 1957  38333     ...  Charles Burns
# 2635  17411703  ...  J. Kenner
# 3128  22611920  ...  Kristen Callihan
# 4255  18594594  ...  Karin Slaughter
# 4285  6303733   ...  Richard Russo, Arthur Morey
#
# [10 rows x 4 columns]

# %% [markdown]
# ### Pregunta 3:
# Comente los resultados obtenidos, en cuanto a modelo de lenguaje, reduccion de dimensionalidad y métrica de distancia utilizada.

# %% [markdown]
# ### Respuesta 3:

# %% [markdown]
# # Recomendaciones

# %%
# format results 
pd.options.display.max_colwidth = 50
pd.set_option('display.max_colwidth', -1)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# ## Función para obtener recomendacion para cada usuario

# %%
def recommend(embedding, user_id=None, topk=10, metric='cosine'):
    
    #print("user_id = ", user_id)
    
    user_id = str(user_id)
    
    #Calculate distance metrics
    trx = user_interactions[user_id]
    n = embedding.shape[0]
    distances = 1e9
    
    # recorremos transacciones pasadas del usuario 
    for t in trx:
        query_i = bookid2idx[t]
        
        # recomendamos items más cercanos a items con los que interactuó el usuario
        distances = np.minimum(distances, pairwise_distances(
                embedding[query_i].reshape(1,-1), embedding, metric=metric).reshape(-1))

    #Rank items de menor a mayor distancia (nos quedamos con los topk)
    trx_set = set(trx)
    heap = []
    for i in range(n):
        if idx2bookid[i] in trx_set:
            continue
        if len(heap) < topk:
            heapq.heappush(heap, (-distances[i], i))
        else:
            heapq.heappushpop(heap, (-distances[i], i))
    heap.sort(reverse=True)
    
    # utilizamos un heap para extraer los items ordenados de menor a mayor distancia 
    recommended_ids = [idx2bookid[i] for _,i in heap]
    
    # retornar los que el usuario no haya consumido 
    filtered_recommended_ids = []
    
    return recommended_ids

# %% [markdown]
# ## generar recomendaciones para un usuario en particular

# %%
# recomendación para el usuario id = 49299 , utilizando bert con reduccion de dimensionalidad a 20 
user_id = '50101'
rec = recommend(pca20_bert_featmat, user_id=user_id, topk=15)
rec
# Out:
# [49596,
#  28703,
#  7805,
#  38500,
#  2161733,
#  26046,
#  2120932,
#  11250317,
#  29800,
#  228296,
#  6050678,
#  39031,
#  25,
#  296264,
#  4162673]

# %% [markdown]
# ## transacciones pasadas del usuario

# %%
past_interactions = user_interactions[str(user_id)]

df_books[df_books['book_id'].isin(past_interactions)][['book_id', 'original_title', 'book_description', 'authors']]
# Out:
#       book_id  ...                      authors
# 1     3        ...  J.K. Rowling, Mary GrandPré
# 18    34       ...  J.R.R. Tolkien
# 23    6        ...  J.K. Rowling, Mary GrandPré
# 50    11       ...  Douglas Adams
# 177   33       ...  J.R.R. Tolkien
# 307   13       ...  Douglas Adams
# 354   50       ...  Gary Paulsen
# 1167  28       ...  Bill Bryson
# 3513  348      ...  Robert A. Heinlein
#
# [9 rows x 4 columns]

# %% [markdown]
# ## información de recomendaciones

# %%
df_books[df_books['book_id'].isin(rec)][['book_id', 'original_title', 'book_description', 'authors']]
# Out:
#        book_id  ...                         authors
# 149   2120932   ...  Rick Riordan
# 660   29800     ...  Bryan Lee O'Malley
# 1026  228296    ...  Ira Levin
# 1350  6050678   ...  Scott Westerfeld
# 1404  2161733   ...  Tom Rob Smith
# 1493  38500     ...  Charles Bukowski
# 1501  25        ...  Bill Bryson
# 1716  11250317  ...  Madeline Miller
# 1752  26046     ...  Nora Roberts
# 2263  7805      ...  Vladimir Nabokov
# 2452  39031     ...  Douglas Preston, Lincoln Child
# 3095  49596     ...  Agatha Christie
# 4201  28703     ...  Don DeLillo
# 4401  296264    ...  Robert Louis Stevenson
# 4651  4162673   ...  P.D. James
#
# [15 rows x 4 columns]

# %% [markdown]
# # evaluación de las recomendaciones con interacciones de testing

# %%
# Métricas de evaluación 
# Obtenido de https://gist.github.com/bwhite/3726239

def precision_at_k(r, k):
    assert k >= 1
    r = np.asarray(r)[:k] != 0
    if r.size != k:
        raise ValueError('Relevance score length < k')
    return np.mean(r)

def average_precision(r):
    r = np.asarray(r) != 0
    out = [precision_at_k(r, k + 1) for k in range(r.size) if r[k]]
    if not out:
        return 0.
    return np.mean(out)

def mean_average_precision(rs):
    return np.mean([average_precision(r) for r in rs])
  
def dcg_at_k(r, k):
    r = np.asfarray(r)[:k]
    if r.size:
        return np.sum(np.subtract(np.power(2, r), 1) / np.log2(np.arange(2, r.size + 2)))
    return 0.


def ndcg_at_k(r, k):
    idcg = dcg_at_k(sorted(r, reverse=True), k)

    if not idcg:
        return 0.
    return dcg_at_k(r, k) / idcg

# %% [markdown]
# ## Evaluación de recomendación con BERT

# %%
start = time.time()

mean_map = 0.
mean_ndcg = 0.

embeddings = pca20_bert_featmat
topk = 10 

for i, u in enumerate(user_interactions_test.keys()):
    
    print(i, end= '\r')
    
    rec = recommend(bert_featmat, user_id = u, topk=topk)
    rel_vector = [np.isin(user_interactions_test[u], rec, assume_unique=True).astype(int)]
    mean_map += mean_average_precision(rel_vector)
    mean_ndcg += ndcg_at_k(rel_vector, topk)

mean_map /= len(user_interactions_test)
mean_ndcg /= len(user_interactions_test)

time_taken = time.time() - start

# %%
print('MAP ',mean_map)
print('ndcg@10' ,mean_ndcg)
print('tiempo de ejecucion {0:.2f} segs'.format(time_taken))
# Out:
# MAP  0.005180859080633007
# ndcg@10 0.006154232604873147
# tiempo de ejecucion 409.41 segs

# %% [markdown]
# ## Evaluación de recomendación con BERT reducidos con PCA-20

# %%
start = time.time()

mean_map = 0.
mean_ndcg = 0.

embeddings = pca20_bert_featmat
topk = 10 

for i, u in enumerate(user_interactions_test.keys()):
    
    print(i, end= '\r')
    
    rec = recommend(pca20_bert_featmat, user_id = u, topk=topk)
    rel_vector = [np.isin(user_interactions_test[u], rec, assume_unique=True).astype(int)]
    mean_map += mean_average_precision(rel_vector)
    mean_ndcg += ndcg_at_k(rel_vector, topk)

mean_map /= len(user_interactions_test)
mean_ndcg /= len(user_interactions_test)

time_taken = time.time() - start

# %%
print('MAP ',mean_map)
print('ndcg@10' ,mean_ndcg)
print('tiempo de ejecucion {0:.2f} segs'.format(time_taken))
# Out:
# MAP  0.005289709453236206
# ndcg@10 0.006279829188646069
# tiempo de ejecucion 74.25 segs

# %% [markdown]
# ## Evaluación de recomendación con BERT-large

# %%
start = time.time()

mean_map = 0.
mean_ndcg = 0.

topk = 10 

for i, u in enumerate(user_interactions_test.keys()):
    
    print(i, end= '\r')
    
    rec = recommend(bert_large_featmat, user_id = u, topk=topk)
    rel_vector = [np.isin(user_interactions_test[u], rec, assume_unique=True).astype(int)]
    mean_map += mean_average_precision(rel_vector)
    mean_ndcg += ndcg_at_k(rel_vector, topk)

mean_map /= len(user_interactions_test)
mean_ndcg /= len(user_interactions_test)

time_taken = time.time() - start

# %%
print('MAP ',mean_map)
print('ndcg@10' ,mean_ndcg)
print('tiempo de ejecucion {0:.2f} segs'.format(time_taken))
# Out:
# MAP  0.0040714225906388676
# ndcg@10 0.00552624968600854
# tiempo de ejecucion 513.96 segs

# %% [markdown]
# ## Evaluación de recomendación con BERT-large reducidos con PCA-20

# %%
start = time.time()

mean_map = 0.
mean_ndcg = 0.

topk = 10 

for i, u in enumerate(user_interactions_test.keys()):
    
    print(i, end= '\r')
    
    rec = recommend(pca20_bert_large_featmat, user_id = u, topk=topk)
    rel_vector = [np.isin(user_interactions_test[u], rec, assume_unique=True).astype(int)]
    mean_map += mean_average_precision(rel_vector)
    mean_ndcg += ndcg_at_k(rel_vector, topk)

mean_map /= len(user_interactions_test)
mean_ndcg /= len(user_interactions_test)

time_taken = time.time() - start

# %%
print('MAP ',mean_map)
print('ndcg@10' ,mean_ndcg)
print('tiempo de ejecucion {0:.2f} segs'.format(time_taken))
# Out:
# MAP  0.0036811760624872905
# ndcg@10 0.00452147701582517
# tiempo de ejecucion 75.54 segs

# %% [markdown]
# ### Pregunta 4:
# - Comente los resultados en términos de tiempo de ejecución y métricas de ranking para los 4 modelos.

# %% [markdown]
# ### Respuesta 4:
